# %% [markdown]
# <a href="https://colab.research.google.com/github/KolekarPramod/Specialized-LLM-Bot/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_json("hf://datasets/medalpaca/medical_meadow_wikidoc/medical_meadow_wikidoc.json")

# %%
df
# Out:
#                           instruction  \
# 0     Answer this question truthfully
# 1     Answer this question truthfully
# 2     Answer this question truthfully
# 3     Answer this question truthfully
# 4     Answer this question truthfully
# ...                               ...
# 9995  Answer this question truthfully
# 9996  Answer this question truthfully
# 9997  Answer this question truthfully
# 9998  Answer this question truthfully
# 9999  Answer this question truthfully
#
#                                                                                                input  \
# 0                                 Can you provide an overview of the lung's squamous cell carcinoma?
# 1                                                                      What does "Clear: cell" mean?
# 2                                             Can you provide me with information regarding statins?
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
df['len'] = df['output'].apply(lambda x:len(x))

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.head(1000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  10000 non-null  object
#  1   input        10000 non-null  object
#  2   output       10000 non-null  object
#  3   len          10000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df =df[(df['len']>200) & (df['len']<400)]

# %%
df
# Out:
#                           instruction  \
# 8     Answer this question truthfully
# 13    Answer this question truthfully
# 14    Answer this question truthfully
# 15    Answer this question truthfully
# 16    Answer this question truthfully
# ...                               ...
# 9980  Answer this question truthfully
# 9988  Answer this question truthfully
# 9993  Answer this question truthfully
# 9997  Answer this question truthfully
# 9999  Answer this question truthfully
#
#                                                                                                            input  \
# 8                                                                 What is the proper treatment for Lymphangioma?
# 13                                              What is the history of leiomyosarcoma and what are its symptoms?
# 14    What diagnostic tests are required for an individual with liver disease who is struggling with alcoholism?
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2268 entries, 8 to 9999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  2268 non-null   object
#  1   input        2268 non-null   object
#  2   output       2268 non-null   object
#  3   len          2268 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 88.6+ KB

# %%
df.drop(columns=['len','instruction'],inplace=True)
# Out:
# /tmp/ipython-input-33-2930220073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['len','instruction'],inplace=True)

# %%
df
# Out:
#                                                                                                            input  \
# 8                                                                 What is the proper treatment for Lymphangioma?
# 13                                              What is the history of leiomyosarcoma and what are its symptoms?
# 14    What diagnostic tests are required for an individual with liver disease who is struggling with alcoholism?
# 15                        Are echocardiography or ultrasound used to detect pericarditis in cases of malignancy?
# 16                       What are the roles of echocardiography and ultrasound in the diagnosis of Endocarditis?
# ...                                                                                                          ...
# 9980                                                What are the history and symptoms of second-degree AV block?
# ...

# %%
df.to_json('medical_meadow_wikidoc_1k.json', indent=4, orient='records')
